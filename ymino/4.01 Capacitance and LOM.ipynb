# %% [markdown]
# # Capacitance matrix and LOM analysis
# ### Prerequisite
# You need to have a working local installation of Ansys.

# %% [markdown]
# ## 1. Create the design in Metal

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, Headings

# %%
design = designs.DesignPlanar()
gui = MetalGUI(design)

from qiskit_metal.qlibrary.qubits.transmon_pocket import TransmonPocket
from qiskit_metal.qlibrary.tlines.meandered import RouteMeander

# %%
design.variables['cpw_width'] = '15 um'
design.variables['cpw_gap'] = '9 um'

# %% [markdown]
# ### In this example, the design consists of 4 qubits and 4 CPWs

# %%
# Allow running the same cell here multiple times to overwrite changes
design.overwrite_enabled = True

## Custom options for all the transmons
options = dict(
    # Some options we want to modify from the defaults
    # (see below for defaults)
    pad_width = '425 um', 
    pocket_height = '650um',
    # Adding 4 connectors (see below for defaults)
    connection_pads=dict(
        readout = dict(loc_W=+1,loc_H=-1, pad_width='200um'),
        bus1 = dict(loc_W=-1,loc_H=+1, pad_height='30um'),
        bus2 = dict(loc_W=-1,loc_H=-1, pad_height='50um')
    )
)

## Create 4 transmons

q1 = TransmonPocket(design, 'Q1', options = dict(
    pos_x='+2.42251mm', pos_y='+0.0mm', **options))
q2 = TransmonPocket(design, 'Q2', options = dict(
    pos_x='+0.0mm', pos_y='-0.95mm', orientation = '270', **options))
q3 = TransmonPocket(design, 'Q3', options = dict(
    pos_x='-2.42251mm', pos_y='+0.0mm', orientation = '180', **options))
q4 = TransmonPocket(design, 'Q4', options = dict(
    pos_x='+0.0mm', pos_y='+0.95mm', orientation = '90', **options))

RouteMeander.get_template_options(design)

options = Dict(
        lead=Dict(
            start_straight='0.2mm',
            end_straight='0.2mm'),
        trace_gap='9um',
        trace_width='15um')

def connect(component_name: str, component1: str, pin1: str, component2: str, pin2: str,
            length: str, asymmetry='0 um', flip=False, fillet='90um'):
    """Connect two pins with a CPW."""
    myoptions = Dict(
        fillet=fillet,
        hfss_wire_bonds = True,
        pin_inputs=Dict(
            start_pin=Dict(
                component=component1,
                pin=pin1),
            end_pin=Dict(
                component=component2,
                pin=pin2)),
        total_length=length)
    myoptions.update(options)
    myoptions.meander.asymmetry = asymmetry
    myoptions.meander.lead_direction_inverted = 'true' if flip else 'false'
    return RouteMeander(design, component_name, myoptions)

asym = 140
cpw1 = connect('cpw1', 'Q1', 'bus2', 'Q2', 'bus1', '6.0 mm', f'+{asym}um')
cpw2 = connect('cpw2', 'Q3', 'bus1', 'Q2', 'bus2', '6.1 mm', f'-{asym}um', flip=True)
cpw3 = connect('cpw3', 'Q3', 'bus2', 'Q4', 'bus1', '6.0 mm', f'+{asym}um')
cpw4 = connect('cpw4', 'Q1', 'bus1', 'Q4', 'bus2', '6.1 mm', f'-{asym}um', flip=True)

gui.rebuild()
gui.autoscale()

# %% [markdown]
# ## 2. Capacitance Analysis and LOM derivation using the analysis package - most users

# %% [markdown]
# ### Capacitance Analysis
# Select the analysis you intend to run from the `qiskit_metal.analyses` collection.<br>
# Select the design to analyze and the tool to use for any external simulation

# %%
from qiskit_metal.analyses.quantization import LOManalysis
c1 = LOManalysis(design, "q3d")

# %% [markdown]
# (optional) You can review and update the Analysis default setup following the examples in the next two cells.

# %%
c1.sim.setup
# Out:
# {'name': 'Setup',
#  'reuse_selected_design': True,
#  'reuse_setup': True,
#  'freq_ghz': 5.0,
#  'save_fields': False,
#  'enabled': True,
#  'max_passes': 15,
#  'min_passes': 2,
#  'min_converged_passes': 2,
#  'percent_error': 0.5,
#  'percent_refinement': 30,
#  'auto_increase_solution_order': True,
#  'solution_order': 'High',
#  'solver_type': 'Iterative'}

# %%
# example: update single setting
c1.sim.setup.max_passes = 6
# example: update multiple settings
c1.sim.setup_update(solution_order = 'Medium', auto_increase_solution_order = 'False')

c1.sim.setup
# Out:
# {'name': 'Setup',
#  'reuse_selected_design': True,
#  'reuse_setup': True,
#  'freq_ghz': 5.0,
#  'save_fields': False,
#  'enabled': True,
#  'max_passes': 6,
#  'min_passes': 2,
#  'min_converged_passes': 2,
#  'percent_error': 0.5,
#  'percent_refinement': 30,
#  'auto_increase_solution_order': 'False',
#  'solution_order': 'Medium',
#  'solver_type': 'Iterative'}

# %% [markdown]
# Analyze a single qubit with 2 endcaps using the default (or edited) analysis setup. Then show the capacitance matrix (from the last pass).
#
# You can use the method `run()` instead of `sim.run()` in the following cell if you want to run both cap extraction and lom analysis in a single step. If so, make sure to also tweak the setup for the lom analysis. The input parameters are otherwise the same for the two methods.

# %%
c1.sim.run(components=['Q1'], open_terminations=[('Q1', 'readout'), ('Q1', 'bus1'), ('Q1', 'bus2')])
c1.sim.capacitance_matrix
# Out:
# INFO 11:34PM [connect_project]: Connecting to Ansys Desktop API...
# INFO 11:34PM [load_ansys_project]: 	Opened Ansys App
# INFO 11:34PM [load_ansys_project]: 	Opened Ansys Desktop v2023.2.0
# INFO 11:34PM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    C:/Users/ymino/Documents/Ansoft/
# 	Project:   Project3
# INFO 11:34PM [connect_design]: No active design found (or error getting active design).
# INFO 11:34PM [connect]: 	 Connected to project "Project3". No design detected
# INFO 11:34PM [connect_design]: 	Opened active design
# 	Design:    Design_q3d [Solution type: Q3D]
# WARNING 11:34PM [connect_setup]: 	No design setup detected.
# WARNING 11:34PM [connect_setup]: 	Creating Q3D default setup.
# INFO 11:34PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# =======================================
# self.design.solution_type : Q3D
# setup.name                : Setup
# =======================================
# =========================================
# get_setup in pyEPR
# self.solution_type : Q3D
# =========================================
# INFO 11:34PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 11:34PM [analyze]: Analyzing setup Setup
# =========================================
# get_setup in pyEPR
# self.solution_type : Q3D
# =========================================
# INFO 11:34PM [get_matrix]: Exporting matrix data to (C:\Users\ymino\AppData\Local\Temp\5\tmpaju9wqvm.txt, C, , Setup:LastAdaptive, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 1, False
# INFO 11:34PM [get_matrix]: Exporting matrix data to (C:\Users\ymino\AppData\Local\Temp\5\tmp6_gy642_.txt, C, , Setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 1, False
# INFO 11:34PM [get_matrix]: Exporting matrix data to (C:\Users\ymino\AppData\Local\Temp\5\tmpaifmd8ks.txt, C, , Setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 2, False
# INFO 11:34PM [get_matrix]: Exporting matrix data to (C:\Users\ymino\AppData\Local\Temp\5\tmps4z4jpyf.txt, C, , Setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 3, False
# INFO 11:34PM [get_matrix]: Exporting matrix data to (C:\Users\ymino\AppData\Local\Temp\5\tmp20ew0qhq.txt, C, , Setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 4, False
# INFO 11:34PM [get_matrix]: Exporting matrix data to (C:\Users\ymino\AppData\Local\Temp\5\tmp5foupyvi.txt, C, , Setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 5, False
# INFO 11:34PM [get_matrix]: Exporting matrix data to (C:\Users\ymino\AppData\Local\Temp\5\tmpl0cjhwyd.txt, C, , Setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 6, False
# INFO 11:34PM [get_matrix]: Exporting matrix data to (C:\Users\ymino\AppData\Local\Temp\5\tmpseq7_f0r.txt, C, , Setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 7, False
#                           bus1_connector_pad_Q1  bus2_connector_pad_Q1  \
# bus1_connector_pad_Q1                  49.81916               -0.42243
# bus2_connector_pad_Q1                  -0.42243               53.94437
# ground_main_plane                     -33.47372              -35.81374
# pad_bot_Q1                             -1.56619              -13.86735
# pad_top_Q1                            -13.23557               -1.83231
# readout_connector_pad_Q1               -0.20510               -1.01548
#
#                           ground_main_plane  pad_bot_Q1  pad_top_Q1  \
# bus1_connector_pad_Q1             -33.47372    -1.56619   -13.23557
# bus2_connector_pad_Q1             -35.81374   -13.86735    -1.83231
# ground_main_plane                 237.80294   -31.52793   -37.95933
# pad_bot_Q1                        -31.52793    98.12445   -30.21163
# pad_top_Q1                        -37.95933   -30.21163    88.15055
# readout_connector_pad_Q1          -36.57183   -18.79337    -2.21079
#
#                           readout_connector_pad_Q1
# bus1_connector_pad_Q1                     -0.20510
# bus2_connector_pad_Q1                     -1.01548
# ground_main_plane                        -36.57183
# pad_bot_Q1                               -18.79337
# pad_top_Q1                                -2.21079
# readout_connector_pad_Q1                  59.86760

# %% [markdown]
# (otional - case-dependent)<br>If the previous cell was interrupted due to license limitations and for any reason you finally manually launched the simulation from the renderer GUI (outside qiskit-metal) you might be able to recover the simulation results by uncommenting and executing the following cell

# %%
#c1.sim._get_results_from_renderer()
#c1.sim.capacitance_matrix

# %% [markdown]
# The last variables you pass to the `run()` or `sim.run()` methods, will be stored in the `sim.setup` dictionary under the key `run`. You can recall the information passed by either accessing the dictionary directly, or by using the print handle below.

# %%
# c1.setup.run    <- direct access
c1.sim.print_run_args()
# Out:
# This analysis object run with the following kwargs:
# {'name': None, 'components': ['Q1'], 'open_terminations': [('Q1', 'readout'), ('Q1', 'bus1'), ('Q1', 'bus2')], 'box_plus_buffer': True}

# %% [markdown]
# You can re-run the analysis after varying the parameters.<br>
# Not passing the parameter `components` to the `sim.run()` method, skips the rendering and tries to run the analysis on the latest design. If a design is not found, the full metal design is rendered.

# %%
c1.sim.setup.freq_ghz = 4.8
c1.sim.run()
c1.sim.capacitance_matrix
# Out:
# INFO 11:34PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 11:34PM [analyze]: Analyzing setup Setup
# =========================================
# get_setup in pyEPR
# self.solution_type : Q3D
# =========================================
# INFO 11:34PM [get_matrix]: Exporting matrix data to (C:\Users\ymino\AppData\Local\Temp\5\tmp9xfpcpeq.txt, C, , Setup:LastAdaptive, "Original", "ohm", "nH", "fF", "mSie", 4800000000, Maxwell, 1, False
# INFO 11:34PM [get_matrix]: Exporting matrix data to (C:\Users\ymino\AppData\Local\Temp\5\tmpdeipvr9m.txt, C, , Setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 4800000000, Maxwell, 1, False
# INFO 11:34PM [get_matrix]: Exporting matrix data to (C:\Users\ymino\AppData\Local\Temp\5\tmpj_vkv57b.txt, C, , Setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 4800000000, Maxwell, 2, False
# INFO 11:34PM [get_matrix]: Exporting matrix data to (C:\Users\ymino\AppData\Local\Temp\5\tmptp71p79h.txt, C, , Setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 4800000000, Maxwell, 3, False
# INFO 11:34PM [get_matrix]: Exporting matrix data to (C:\Users\ymino\AppData\Local\Temp\5\tmpweudksnh.txt, C, , Setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 4800000000, Maxwell, 4, False
# INFO 11:34PM [get_matrix]: Exporting matrix data to (C:\Users\ymino\AppData\Local\Temp\5\tmpnrklp7ux.txt, C, , Setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 4800000000, Maxwell, 5, False
# INFO 11:34PM [get_matrix]: Exporting matrix data to (C:\Users\ymino\AppData\Local\Temp\5\tmpmf__dhgi.txt, C, , Setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 4800000000, Maxwell, 6, False
# INFO 11:34PM [get_matrix]: Exporting matrix data to (C:\Users\ymino\AppData\Local\Temp\5\tmppxp972yu.txt, C, , Setup:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 4800000000, Maxwell, 7, False
#                           bus1_connector_pad_Q1  bus2_connector_pad_Q1  \
# bus1_connector_pad_Q1                  49.81916               -0.42243
# bus2_connector_pad_Q1                  -0.42243               53.94437
# ground_main_plane                     -33.47372              -35.81374
# pad_bot_Q1                             -1.56619              -13.86735
# pad_top_Q1                            -13.23557               -1.83231
# readout_connector_pad_Q1               -0.20510               -1.01548
#
#                           ground_main_plane  pad_bot_Q1  pad_top_Q1  \
# bus1_connector_pad_Q1             -33.47372    -1.56619   -13.23557
# bus2_connector_pad_Q1             -35.81374   -13.86735    -1.83231
# ground_main_plane                 237.80294   -31.52793   -37.95933
# pad_bot_Q1                        -31.52793    98.12445   -30.21163
# pad_top_Q1                        -37.95933   -30.21163    88.15055
# readout_connector_pad_Q1          -36.57183   -18.79337    -2.21079
#
#                           readout_connector_pad_Q1
# bus1_connector_pad_Q1                     -0.20510
# bus2_connector_pad_Q1                     -1.01548
# ground_main_plane                        -36.57183
# pad_bot_Q1                               -18.79337
# pad_top_Q1                                -2.21079
# readout_connector_pad_Q1                  59.86760

# %%
type(c1.sim.capacitance_matrix)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Lumped oscillator model (LOM)
#
# Using capacitance matrices obtained from each pass, save the many parameters of the Hamiltonian of the system. `get_lumped_oscillator()` operates on 4 setup parameters: <br><br>
# Lj: float <br>
# Cj: float <br>
# fr: Union[list, float] <br>
# fb: Union[list, float] <br>

# %%
c1.setup.junctions = Dict({'Lj': 12.31, 'Cj': 2})
c1.setup.freq_readout = 7.0
c1.setup.freq_bus = [6.0, 6.2]

c1.run_lom()
c1.lumped_oscillator_all
# Out:
# [3, 4] [5 0 1]
# Predicted Values
#
# Transmon Properties
# f_Q 5.419121 [GHz]
# EC 311.261797 [MHz]
# EJ 13.273404 [GHz]
# alpha -362.874827 [MHz]
# dispersion 45.611708 [KHz]
# Lq 12.305036 [nH]
# Cq 62.231306 [fF]
# T1 35.937804 [us]
#
# **Coupling Properties**
#
# tCqbus1 7.378437 [fF]
# gbus1_in_MHz 113.980044 [MHz]
# χ_bus1 -3.131320 [MHz]
# 1/T1bus1 2771.370952 [Hz]
# T1bus1 57.428235 [us]
#
# tCqbus2 -6.477983 [fF]
# gbus2_in_MHz -85.977611 [MHz]
# χ_bus2 -9.828684 [MHz]
# 1/T1bus2 1184.141647 [Hz]
# T1bus2 134.405325 [us]
#
# tCqbus3 5.335204 [fF]
# gbus3_in_MHz 73.127847 [MHz]
# χ_bus3 -4.375142 [MHz]
# 1/T1bus3 473.109234 [Hz]
# T1bus3 336.402107 [us]
# Bus-Bus Couplings
# gbus1_2 7.114558 [MHz]
# gbus1_3 9.888706 [MHz]
# gbus2_3 5.359323 [MHz]
#          fQ          EC         EJ       alpha  dispersion  \
# 1  5.748331  353.260691  13.273404 -417.414611  135.303742
# 2  5.647166  340.026238  13.273404 -400.083696   98.212604
# 3  5.557843  328.584272  13.273404 -385.207998   73.285434
# 4  5.492178  320.316969  13.273404 -374.521258   58.729201
# 5   5.44816  314.843106  13.273404 -367.473664   50.474232
# 6  5.419121  311.261797  13.273404 -362.874827   45.611708
#
#                                                 gbus  \
# 1  [108.86761985266924, -73.17555640481613, 76.49...
# 2  [112.02495198591537, -82.73777219537544, 68.84...
# 3  [110.75068052681401, -83.82113715688588, 70.94...
# 4  [110.11045885372712, -84.06707389355425, 71.17...
# 5  [112.62964152978165, -84.55701095809277, 71.59...
# 6  [113.98004350987259, -85.97761066492619, 73.12...
#
#                                           chi_in_MHz    χr MHz      gr MHz
# 1  [-4.799113286754403, -26.580788980047252, -12....  4.799113  108.867620
# 2  [-4.299352186141323, -20.66094554677267, -7.22...  4.299352  112.024952
# 3  [-3.6475720610335176, -14.83842674121245, -5.9...  3.647572  110.750681
# 4  [-3.2597328157788263, -11.85575495065811, -4.9...  3.259733  110.110459
# 5  [-3.1921707419358922, -10.399477899224468, -4....  3.192171  112.629642
# 6  [-3.131320414330654, -9.828684174150355, -4.37...  3.131320  113.980044

# %%
c1.plot_convergence()
c1.plot_convergence_chi()
# Out:
# WARNING:py.warnings:c:\Users\ymino\.conda\envs\qiskit-metal\Lib\site-packages\pyEPR\core_distributed_analysis.py:504: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self._hfss_variables[variation] = pd.Series(
#
# INFO 11:34PM [hfss_report_full_convergence]: Creating report for variation 0
# Design "Design_q3d" info:
# 	# eigenmodes    0
# 	# variations    1

# %% [markdown]
# Once you are done with your analysis, please close it with `close()`. This will free up resources currently occupied by qiskit-metal to communiate with the tool.

# %%
c1.sim.close()

# %% [markdown]
# ## 3. Directly access the renderer to modify other parameters

# %%
c1.sim.start()
c1.sim.renderer
# Out:
# INFO 11:34PM [connect_project]: Connecting to Ansys Desktop API...
# INFO 11:34PM [load_ansys_project]: 	Opened Ansys App
# INFO 11:34PM [load_ansys_project]: 	Opened Ansys Desktop v2023.2.0
# INFO 11:34PM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    C:/Users/ymino/Documents/Ansoft/
# 	Project:   Project3
# INFO 11:34PM [connect_design]: 	Opened active design
# 	Design:    Design_q3d [Solution type: Q3D]
# INFO 11:34PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 11:34PM [connect]: 	Connected to project "Project3" and design "Design_q3d" 😀
# =========================================
# get_setup in pyEPR
# self.solution_type : Q3D
# =========================================

# %% [markdown]
# Every renderer will have its own collection of methods. Below an example with q3d

# %% [markdown]
# ##### Prepare and run a collection of predefined setups
#
# This is equivalent to going to the Project Manager panel in Ansys, right clicking on Analysis within the active Q3D design, selecting "Add Solution Setup...", and choosing/entering default values in the resulting popup window. You might want to do this to keep track of different solution setups, giving each of them a different/specific name.

# %%
setup = c1.sim.renderer.new_ansys_setup(name = "Setup_demo", max_passes = 6)

# %% [markdown]
# You can directly pass to `new_ansys_setup` all the setup parameters. Of course you will then need to run the individual setups by name as well.

# %%
c1.sim.renderer.analyze_setup(setup.name)
# Out:
# INFO 11:34PM [get_setup]: 	Opened setup `Setup_demo`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 11:34PM [analyze]: Analyzing setup Setup_demo
# =========================================
# get_setup in pyEPR
# self.solution_type : Q3D
# =========================================

# %% [markdown]
# ##### Get the capactiance matrix at a different pass
#
# You might want to use this if you intend to know what was the matrix at a different pass of the simulation.

# %%
# Using the analysis results, get its capacitance matrix as a dataframe.
c1.sim.renderer.get_capacitance_matrix(variation = '', solution_kind = 'AdaptivePass', pass_number = 5)
# Out:
# INFO 11:35PM [get_matrix]: Exporting matrix data to (C:\Users\ymino\AppData\Local\Temp\5\tmplq0g5p0s.txt, C, , Setup_demo:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 5, False
# (                          bus1_connector_pad_Q1  bus2_connector_pad_Q1  \
#  bus1_connector_pad_Q1                  48.99347               -0.42235
#  bus2_connector_pad_Q1                  -0.42235               52.97064
#  ground_main_plane                     -32.99092              -35.26835
#  pad_bot_Q1                             -1.53888              -13.44109
#  pad_top_Q1                            -12.93518               -1.81606
#  readout_connector_pad_Q1               -0.20643               -1.00431
#
#                            ground_main_plane  pad_bot_Q1  pad_top_Q1  \
#  bus1_connector_pad_Q1             -32.99092    -1.53888   -12.93518
#  bus2_connector_pad_Q1             -35.26835   -13.44109    -1.81606
#  ground_main_plane                 234.25301   -31.45828   -37.86071
#  pad_bot_Q1                        -31.45828    96.93083   -29.79748
#  pad_top_Q1                        -37.86071   -29.79748    87.33101
#  readout_connector_pad_Q1          -36.12069   -18.37962    -2.21280
#
#                            readout_connector_pad_Q1
#  bus1_connector_pad_Q1                     -0.20643
#  bus2_connector_pad_Q1                     -1.00431
#  ground_main_plane                        -36.12069
#  pad_bot_Q1                               -18.37962
#  pad_top_Q1                                -2.21280
#  readout_connector_pad_Q1                  59.02957  ,
#  'fF')

# %% [markdown]
# ### Code to swap rows and columns in capacitance matrix
# from qiskit_metal.analyses.quantization.lumped_capacitive import df_reorder_matrix_basis
#
# df_reorder_matrix_basis(fourq_q3d.get_capacitance_matrix(), 1, 2)

# %% [markdown]
# ##### Close the renderer

# %%
c1.sim.close()
