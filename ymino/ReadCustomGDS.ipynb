# %%
# %load_ext autoreload
# %autoreload 2

# %%
from modules.MyQComponent import MyQComponent
import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, open_docs
from qiskit_metal.qlibrary.terminations.launchpad_wb_driven import LaunchpadWirebondDriven
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2961, in run_cell
#     result = self._run_cell(
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3016, in _run_cell
#     result = runner(coro)
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3221, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3400, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3460, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/yb/m43009316szdlr_5v9svwy300000gp/T/ipykernel_25742/125092209.py", line 1, in <module>
#     from modules.MyQComponent import MyQComponent
#   File "/Users/yuya/Desktop/Quantum/GDS/qiskit-metal/ymino/modules/MyQComponent.py", line 1, in <module>
#     from qiskit_metal import draw, Dict
#   File "/Users/yuya/Desktop/Quantum/GDS/qiskit-metal/qiskit_metal/__init__.py", line 116, in <module>
#     __setup_Qt_backend()
#   File "/Users/yuya/Desktop/Quantum/GDS/qiskit-metal/qiskit_metal/__init__.py", line 109, in __setup_Qt_backend
#     import matplotlib as mpl
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/shiboken2/files.dir/shibokensupport/feature.py", line 139, in _import
#     return original_import(name, *args, **kwargs)
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/matplotlib/__init__.py", line 131, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/shiboken2/files.dir/shibokensupport/feature.py", line 139, in _import
#     return original_import(name, *args, **kwargs)
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/matplotlib/rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/shiboken2/files.dir/shibokensupport/feature.py", line 139, in _import
#     return original_import(name, *args, **kwargs)
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/matplotlib/colors.py", line 56, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/shiboken2/files.dir/shibokensupport/feature.py", line 139, in _import
#     return original_import(name, *args, **kwargs)
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/matplotlib/scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/shiboken2/files.dir/shibokensupport/feature.py", line 139, in _import
#     return original_import(name, *args, **kwargs)
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/matplotlib/ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/shiboken2/files.dir/shibokensupport/feature.py", line 139, in _import
#     return original_import(name, *args, **kwargs)
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/matplotlib/transforms.py", line 49, in <module>
#     from matplotlib._path import (
#   File "/opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/shiboken2/files.dir/shibokensupport/feature.py", line 139, in _import
#     return original_import(name, *args, **kwargs)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from modules.MyQComponent import MyQComponent
#       2 import qiskit_metal as metal
#       3 from qiskit_metal import designs, draw
#
# File ~/Desktop/Quantum/GDS/qiskit-metal/ymino/modules/MyQComponent.py:1
# ----> 1 from qiskit_metal import draw, Dict
#       2 from qiskit_metal.qlibrary.core import QComponent
#       3 import gdspy
#
# File ~/Desktop/Quantum/GDS/qiskit-metal/qiskit_metal/__init__.py:116
#     112         import matplotlib.pyplot as plt
#     113         plt.ion()  # interactive
# --> 116 __setup_Qt_backend()
#     117 del __setup_Qt_backend
#     119 ## Setup logging
#
# File ~/Desktop/Quantum/GDS/qiskit-metal/qiskit_metal/__init__.py:109, in __setup_Qt_backend()
#     103         # Other options of interest:
#     104         # AA_DontUseNativeMenuBar
#     105         # AA_MacDontSwapCtrlAndMeta
#     107 if not os.getenv('QISKIT_METAL_HEADLESS', None):
#     108     # pylint: disable=import-outside-toplevel
# --> 109     import matplotlib as mpl
#     110     mpl.use("Qt5Agg")
#     111     # pylint: disable=redefined-outer-name
#
# File /opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/shiboken2/files.dir/shibokensupport/feature.py:139, in _import(name, *args, **kwargs)
#     137     default = 0 if name.split(".")[0] == "PySide2" else -1
#     138     pyside_feature_dict[importing_module] = default
# --> 139 return original_import(name, *args, **kwargs)
#
# File /opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/matplotlib/__init__.py:131
#     127 from packaging.version import parse as parse_version
#     129 # cbook must import matplotlib only within function
#     130 # definitions, so it is safe to import from it here.
# --> 131 from . import _api, _version, cbook, _docstring, rcsetup
#     132 from matplotlib.cbook import sanitize_sequence
#     133 from matplotlib._api import MatplotlibDeprecationWarning
#
# File /opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/shiboken2/files.dir/shibokensupport/feature.py:139, in _import(name, *args, **kwargs)
#     137     default = 0 if name.split(".")[0] == "PySide2" else -1
#     138     pyside_feature_dict[importing_module] = default
# --> 139 return original_import(name, *args, **kwargs)
#
# File /opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/matplotlib/rcsetup.py:27
#      25 from matplotlib import _api, cbook
#      26 from matplotlib.cbook import ls_mapper
# ---> 27 from matplotlib.colors import Colormap, is_color_like
#      28 from matplotlib._fontconfig_pattern import parse_fontconfig_pattern
#      29 from matplotlib._enums import JoinStyle, CapStyle
#
# File /opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/shiboken2/files.dir/shibokensupport/feature.py:139, in _import(name, *args, **kwargs)
#     137     default = 0 if name.split(".")[0] == "PySide2" else -1
#     138     pyside_feature_dict[importing_module] = default
# --> 139 return original_import(name, *args, **kwargs)
#
# File /opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/matplotlib/colors.py:56
#      54 import matplotlib as mpl
#      55 import numpy as np
# ---> 56 from matplotlib import _api, _cm, cbook, scale
#      57 from ._color_data import BASE_COLORS, TABLEAU_COLORS, CSS4_COLORS, XKCD_COLORS
#      60 class _ColorMapping(dict):
#
# File /opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/shiboken2/files.dir/shibokensupport/feature.py:139, in _import(name, *args, **kwargs)
#     137     default = 0 if name.split(".")[0] == "PySide2" else -1
#     138     pyside_feature_dict[importing_module] = default
# --> 139 return original_import(name, *args, **kwargs)
#
# File /opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/matplotlib/scale.py:22
#      20 import matplotlib as mpl
#      21 from matplotlib import _api, _docstring
# ---> 22 from matplotlib.ticker import (
#      23     NullFormatter, ScalarFormatter, LogFormatterSciNotation, LogitFormatter,
#      24     NullLocator, LogLocator, AutoLocator, AutoMinorLocator,
#      25     SymmetricalLogLocator, AsinhLocator, LogitLocator)
#      26 from matplotlib.transforms import Transform, IdentityTransform
#      29 class ScaleBase:
#
# File /opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/shiboken2/files.dir/shibokensupport/feature.py:139, in _import(name, *args, **kwargs)
#     137     default = 0 if name.split(".")[0] == "PySide2" else -1
#     138     pyside_feature_dict[importing_module] = default
# --> 139 return original_import(name, *args, **kwargs)
#
# File /opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/matplotlib/ticker.py:138
#     136 import matplotlib as mpl
#     137 from matplotlib import _api, cbook
# --> 138 from matplotlib import transforms as mtransforms
#     140 _log = logging.getLogger(__name__)
#     142 __all__ = ('TickHelper', 'Formatter', 'FixedFormatter',
#     143            'NullFormatter', 'FuncFormatter', 'FormatStrFormatter',
#     144            'StrMethodFormatter', 'ScalarFormatter', 'LogFormatter',
#    (...)
#     150            'MultipleLocator', 'MaxNLocator', 'AutoMinorLocator',
#     151            'SymmetricalLogLocator', 'AsinhLocator', 'LogitLocator')
#
# File /opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/shiboken2/files.dir/shibokensupport/feature.py:139, in _import(name, *args, **kwargs)
#     137     default = 0 if name.split(".")[0] == "PySide2" else -1
#     138     pyside_feature_dict[importing_module] = default
# --> 139 return original_import(name, *args, **kwargs)
#
# File /opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/matplotlib/transforms.py:49
#      46 from numpy.linalg import inv
#      48 from matplotlib import _api
# ---> 49 from matplotlib._path import (
#      50     affine_transform, count_bboxes_overlapping_bbox, update_path_extents)
#      51 from .path import Path
#      53 DEBUG = False
#
# File /opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/shiboken2/files.dir/shibokensupport/feature.py:139, in _import(name, *args, **kwargs)
#     137     default = 0 if name.split(".")[0] == "PySide2" else -1
#     138     pyside_feature_dict[importing_module] = default
# --> 139 return original_import(name, *args, **kwargs)
#
# ImportError: numpy.core.multiarray failed to import

# %%
design = designs.DesignPlanar()
design._chips['main']['size']['size_x'] = '9mm'
design._chips['main']['size']['size_y'] = '9mm'
gui = MetalGUI(design)
design.overwrite_enabled = True
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 design = designs.DesignPlanar()
#       2 design._chips['main']['size']['size_x'] = '9mm'
#       3 design._chips['main']['size']['size_y'] = '9mm'
#
# File ~/Desktop/Quantum/GDS/qiskit-metal/qiskit_metal/designs/design_planar.py:46, in DesignPlanar.__init__(self, metadata, overwrite_enabled, enable_renderers)
#      34 def __init__(self,
#      35              metadata: dict = None,
#      36              overwrite_enabled: bool = False,
#      37              enable_renderers: bool = True):
#      38     """Pass metadata to QDesign.
#      39
#      40     Args:
#    (...)
#      43         enable_renderers (bool, optional): Passed to QDesign base class. Defaults to True.
#      44     """
# ---> 46     super().__init__(metadata=metadata,
#      47                      overwrite_enabled=overwrite_enabled,
#      48                      enable_renderers=enable_renderers)
#      49     self.add_chip_info()
#
# File ~/Desktop/Quantum/GDS/qiskit-metal/qiskit_metal/designs/design_base.py:152, in QDesign.__init__(self, metadata, overwrite_enabled, enable_renderers)
#     150 self._renderers = Dict()
#     151 if enable_renderers:
# --> 152     self._start_renderers()
#     154 # Take out of the QGeometryTables init().
#     155 # Add add_renderer_extension() during renderer's init().
#     156 # Need to add columns to Junction tables before create_tables().
#     157 self._qgeometry.create_tables()
#
# File ~/Desktop/Quantum/GDS/qiskit-metal/qiskit_metal/designs/design_base.py:924, in QDesign._start_renderers(self)
#     922 # check if module_name exists
#     923 if importlib.util.find_spec(path_name):
# --> 924     class_renderer = getattr(importlib.import_module(path_name),
#     925                              class_name, None)
#     927     # check if class_name is in module
#     928     if class_renderer is not None:
#
# File /opt/anaconda3/envs/qiskit-metal/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/Desktop/Quantum/GDS/qiskit-metal/qiskit_metal/renderers/renderer_gmsh/gmsh_renderer.py:4
#       2 from collections import defaultdict
#       3 import pandas as pd
# ----> 4 import gmsh
#       5 import numpy as np
#       7 from qiskit_metal.renderers.renderer_base import QRenderer
#
# File /opt/anaconda3/envs/qiskit-metal/lib/python3.11/site-packages/shiboken2/files.dir/shibokensupport/feature.py:139, in _import(name, *args, **kwargs)
#     137     default = 0 if name.split(".")[0] == "PySide2" else -1
#     138     pyside_feature_dict[importing_module] = default
# --> 139 return original_import(name, *args, **kwargs)
#
# ModuleNotFoundError: No module named 'gmsh'

# %%
# Select a QComponent to create (The QComponent is a python class named `TransmonPocket`)
from qiskit_metal.qlibrary.qubits.transmon_pocket import TransmonPocket

# %%
# Create a new qcomponent object with name 'Q1' 
#q1 = TransmonPocket(design, 'Q1')
#gui.rebuild()  # rebuild the design and plot

# %%
test = MyQComponent(design, 'test')

# Driven Lauchpad 1
x = '-1.5mm'
y = '2.0mm'
launch_options = dict(chip='main', pos_x=x, pos_y=y, orientation='360', lead_length='30um')
LP1 = LaunchpadWirebondDriven(design, 'LP1', options = launch_options)
design.components.LP1.pins.keys()

gui.rebuild()  # rebuild the design and plot

# %%
component = "test"
gui.rebuild()
#gui.autoscale()
#gui.edit_component(component)
gui.zoom_on_components([component])
gui.highlight_components([component])
gui.screenshot()
